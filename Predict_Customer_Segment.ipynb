# %% [markdown]
# <a href="https://colab.research.google.com/github/SergioDLezama/Estadistica-Descriptiva-Platzi/blob/main/Predict_Customer_Segment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SergioDLezama/Retail-Analysis
# Out:
# fatal: destination path 'Retail-Analysis' already exists and is not an empty directory.

# %%
#!pip install scikeras

# %%
#!pip install keras-tuner

# %%
# Importing necesaries libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
from sklearn import tree
from sklearn import metrics
from sklearn import model_selection
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, recall_score

from scikeras.wrappers import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from keras_tuner import RandomSearch
from tensorflow.keras import backend

import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# %%
sns.set_style("whitegrid")

# %%
sns.set_palette('Blues_r')

# %%
df = pd.read_csv('/content/Retail-Analysis/retail_data.csv')

# %%
data = df.copy()

# %%
df.head(3)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0      8691788.00     37249.00  Michelle Harrington  Ebony39@gmail.com
# 1      2174773.00     69749.00          Kelsey Hill   Mark36@gmail.com
# 2      6679610.00     30192.00         Scott Jensen  Shane85@gmail.com
#
#           Phone             Address        City            State  Zipcode  \
# 0 1414786801.00   3959 Amanda Burgs    Dortmund           Berlin 77985.00
# 1 6852899987.00  82072 Dawn Centers  Nottingham          England 99071.00
# 2 8362160449.00   4133 Young Canyon     Geelong  New South Wales 75929.00
#
#      Country   Age  Gender Income Customer_Segment        Date    Year  \
# 0    Germany 21.00    Male    Low          Regular   9/18/2023 2023.00
# 1         UK 19.00  Female    Low          Premium  12/31/2023 2023.00
# 2  Australia 48.00    Male    Low          Regular   4/26/2023 2023.00
#
#        Month      Time  Total_Purchases  Amount  Total_Amount  \
# ...

# %%
df.shape
# Out:
# (302010, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
# ...

# %% [markdown]
# ## Data treatment

# %%
df.isnull().sum()
# Out:
# Transaction_ID      333
# Customer_ID         308
# Name                382
# Email               347
# Phone               362
# Address             315
# City                248
# State               281
# Zipcode             340
# Country             271
# Age                 173
# Gender              317
# Income              290
# Customer_Segment    215
# Date                359
# Year                350
# Month               273
# Time                350
# Total_Purchases     361
# Amount              357
# Total_Amount        350
# Product_Category    283
# Product_Brand       281
# Product_Type          0
# Feedback            184
# Shipping_Method     337
# Payment_Method      297
# Order_Status        235
# Ratings             184
# products              0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Customer_ID         0
# Name                0
# Email               0
# Phone               0
# Address             0
# City                0
# State               0
# Zipcode             0
# Country             0
# Age                 0
# Gender              0
# Income              0
# Customer_Segment    0
# Date                0
# Year                0
# Month               0
# Time                0
# Total_Purchases     0
# Amount              0
# Total_Amount        0
# Product_Category    0
# Product_Brand       0
# Product_Type        0
# Feedback            0
# Shipping_Method     0
# Payment_Method      0
# Order_Status        0
# Ratings             0
# products            0
# dtype: int64

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
df.head(3)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0      8691788.00     37249.00  Michelle Harrington  Ebony39@gmail.com
# 1      2174773.00     69749.00          Kelsey Hill   Mark36@gmail.com
# 2      6679610.00     30192.00         Scott Jensen  Shane85@gmail.com
#
#           Phone             Address        City            State  Zipcode  \
# 0 1414786801.00   3959 Amanda Burgs    Dortmund           Berlin 77985.00
# 1 6852899987.00  82072 Dawn Centers  Nottingham          England 99071.00
# 2 8362160449.00   4133 Young Canyon     Geelong  New South Wales 75929.00
#
#      Country   Age  Gender Income Customer_Segment        Date    Year  \
# 0    Germany 21.00    Male    Low          Regular   9/18/2023 2023.00
# 1         UK 19.00  Female    Low          Premium  12/31/2023 2023.00
# 2  Australia 48.00    Male    Low          Regular   4/26/2023 2023.00
#
#        Month      Time  Total_Purchases  Amount  Total_Amount  \
# ...

# %%
df.describe().T
# Out:
#                     count          mean           std           min  \
# Transaction_ID  293911.00    5493725.59    2596085.94    1000007.00
# Customer_ID     293911.00      55013.40      26009.44      10000.00
# Phone           293911.00 5500607077.13 2596111174.73 1000049414.00
# Zipcode         293911.00      50288.38      28976.61        501.00
# Age             293911.00         35.47         15.02         18.00
# Year            293911.00       2023.17          0.37       2023.00
# Total_Purchases 293911.00          5.36          2.87          1.00
# Amount          293911.00        255.15        141.39         10.00
# Total_Amount    293911.00       1367.69       1128.90         10.00
# Ratings         293911.00          3.16          1.32          1.00
#
#                           25%           50%           75%           max
# Transaction_ID     3245885.50    5495879.00    7738197.00    9999995.00
# Customer_ID          32470.00      55027.00      77514.00      99999.00
# ...

# %%
dup = df.duplicated()
df[dup].index
# Out:
# Index([299759, 301362, 301486], dtype='int64')

# %%
df.drop(df.index[dup])
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0           8691788.00     37249.00  Michelle Harrington
# 1           2174773.00     69749.00          Kelsey Hill
# 2           6679610.00     30192.00         Scott Jensen
# 3           7232460.00     62101.00        Joseph Miller
# 4           4983775.00     27901.00        Debra Coleman
# ...                ...          ...                  ...
# 302005      4246475.00     12104.00         Meagan Ellis
# 302006      1197603.00     69772.00          Mathew Beck
# 302007      7743242.00     28449.00           Daniel Lee
# 302008      9301950.00     45477.00       Patrick Wilson
# 302009      2882826.00     53626.00       Dustin Merritt
#
#                            Email         Phone                       Address  \
# 0              Ebony39@gmail.com 1414786801.00             3959 Amanda Burgs
# 1               Mark36@gmail.com 6852899987.00            82072 Dawn Centers
# ...

# %%
df = df.drop_duplicates()

# %%
df['Transaction_ID'].nunique()
# Out:
# 287005

# %%
df['Transaction_ID'].value_counts()
# Out:
# Transaction_ID
# 6145934.00    4
# 9918529.00    3
# 6592672.00    3
# 1858467.00    3
# 2452608.00    3
#              ..
# 4487444.00    1
# 6826016.00    1
# 2050516.00    1
# 6943631.00    1
# 9099074.00    1
# Name: count, Length: 287005, dtype: int64

# %%
df[df['Transaction_ID']==6145934]
# Out:
#         Transaction_ID  Customer_ID            Name                Email  \
# 140676      6145934.00     76353.00  Brian Alvarado  Richard77@gmail.com
# 194626      6145934.00     23433.00      Joel Perry  Tiffany74@gmail.com
# 300648      6145934.00     76353.00  Brian Alvarado  Richard77@gmail.com
# 301371      6145934.00     23433.00      Joel Perry  Tiffany74@gmail.com
#
#                Phone                           Address      City    State  \
# 140676 5080492339.00  62419 Jonathan Orchard Suite 916  Hamilton  Ontario
# 194626 4748727451.00                     572 Hunt Path    Bochum   Berlin
# 300648 5080492339.00  62419 Jonathan Orchard Suite 916  Hamilton  Ontario
# 301371 4748727451.00                     572 Hunt Path    Bochum   Berlin
#
#         Zipcode  Country   Age  Gender  Income Customer_Segment        Date  \
# 140676 89383.00   Canada 26.00    Male  Medium          Regular  11/29/2023
# ...

# %%
duplicate_transaction_ids = df['Transaction_ID'].value_counts()[lambda x: x > 1].index
duplicate_indexes = df[df['Transaction_ID'].isin(duplicate_transaction_ids)].index
df = df.drop(duplicate_indexes)

# %%
df['Transaction_ID'].value_counts()
# Out:
# Transaction_ID
# 2174773.00    1
# 2416371.00    1
# 5736738.00    1
# 5060644.00    1
# 2195548.00    1
#              ..
# 3897203.00    1
# 2970871.00    1
# 3374752.00    1
# 9948479.00    1
# 9099074.00    1
# Name: count, Length: 280216, dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
df.head(1)
# Out:
#    Transaction_ID  Customer_ID         Name             Email         Phone  \
# 0      2174773.00     69749.00  Kelsey Hill  Mark36@gmail.com 6852899987.00
#
#               Address        City    State  Zipcode Country   Age  Gender  \
# 0  82072 Dawn Centers  Nottingham  England 99071.00      UK 19.00  Female
#
#   Income Customer_Segment        Date    Year     Month     Time  \
# 0    Low          Premium  12/31/2023 2023.00  December  8:42:04
#
#    Total_Purchases  Amount  Total_Amount Product_Category Product_Brand  \
# 0             2.00  403.35        806.71      Electronics       Samsung
#
#   Product_Type   Feedback Shipping_Method Payment_Method Order_Status  \
# 0       Tablet  Excellent        Standard    Credit Card   Processing
#
#    Ratings    products
# 0     4.00  Lenovo Tab

# %%
cols_to_drop = ['Name', 'Email', 'Phone', 'Address', 'Zipcode','Time']
df = df.drop(cols_to_drop, axis=1)

# %%
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['City', 'State', 'Country', 'Gender', 'Income', 'Customer_Segment',
#        'Date', 'Month', 'Product_Category', 'Product_Brand', 'Product_Type',
#        'Feedback', 'Shipping_Method', 'Payment_Method', 'Order_Status',
#        'products'],
#       dtype='object')

# %%
df['Country'].value_counts()
# Out:
# Country
# USA          88803
# UK           58603
# Germany      48899
# Australia    41997
# Canada       41914
# Name: count, dtype: int64

# %%
for col in cat_cols:
  print('*'*25)
  print(col)
  print(df[col].value_counts(normalize=True))
# Out:
# *************************
# City
# City
# Chicago         0.07
# Portsmouth      0.07
# San Francisco   0.04
# Frankfurt       0.03
# Boston          0.03
#                 ...
# Kansas City     0.00
# Denver          0.00
# Arlington       0.00
# San Diego       0.00
# Philadelphia    0.00
# Name: proportion, Length: 130, dtype: float64
# *************************
# State
# State
# England           0.21
# Berlin            0.17
# New South Wales   0.15
# Ontario           0.15
# Connecticut       0.07
# Maine             0.04
# Georgia           0.03
# Kansas            0.02
# New Mexico        0.02
# New York          0.00
# Maryland          0.00
# Pennsylvania      0.00
# California        0.00
# Texas             0.00
# Ohio              0.00
# Illinois          0.00
# Nevada            0.00
# South Carolina    0.00
# Hawaii            0.00
# Mississippi       0.00
# Minnesota         0.00
# Michigan          0.00
# Iowa              0.00
# Utah              0.00
# ...

# %%
df.head(1)
# Out:
#    Transaction_ID  Customer_ID        City    State Country   Age  Gender  \
# 0      2174773.00     69749.00  Nottingham  England      UK 19.00  Female
#
#   Income Customer_Segment        Date    Year     Month  Total_Purchases  \
# 0    Low          Premium  12/31/2023 2023.00  December             2.00
#
#    Amount  Total_Amount Product_Category Product_Brand Product_Type  \
# 0  403.35        806.71      Electronics       Samsung       Tablet
#
#     Feedback Shipping_Method Payment_Method Order_Status  Ratings    products
# 0  Excellent        Standard    Credit Card   Processing     4.00  Lenovo Tab

# %% [markdown]
# Dropping columns to use decision tree, random forest and deeplearning to predict Premium Costumers

# %%
cols_to_drop = [
    'Transaction_ID', 'Customer_ID', 'City', 'State', 'Date', 'Year', 'Month', 'Amount', 'products'
]
df = df.drop(cols_to_drop, axis=1)

# %%
df.head(1)
# Out:
#   Country   Age  Gender Income Customer_Segment  Total_Purchases  \
# 0      UK 19.00  Female    Low          Premium             2.00
#
#    Total_Amount Product_Category Product_Brand Product_Type   Feedback  \
# 0        806.71      Electronics       Samsung       Tablet  Excellent
#
#   Shipping_Method Payment_Method Order_Status  Ratings
# 0        Standard    Credit Card   Processing     4.00

# %%
df.Customer_Segment.value_counts()
# Out:
# Customer_Segment
# Regular    136207
# New         84609
# Premium     59400
# Name: count, dtype: int64

# %%
df_copy = df.copy(deep=True)

# %%
new_customers = df_copy[df_copy['Customer_Segment'] == 'New']

df_copy = df_copy[df_copy['Customer_Segment'] != 'New']

df_copy['Customer_Segment'] = df_copy['Customer_Segment'].replace({'Premium': 1, 'Regular': 0})

# %%
numerical_columns = df_copy.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = df_copy.select_dtypes(include=['object']).columns

# %%
df_copy.head()
# Out:
#      Country   Age  Gender  Income  Customer_Segment  Total_Purchases  \
# 0         UK 19.00  Female     Low                 1             2.00
# 1  Australia 48.00    Male     Low                 0             3.00
# 2     Canada 56.00    Male    High                 1             7.00
# 3         UK 22.00    Male     Low                 1             2.00
# 4  Australia 58.00  Female  Medium                 1             4.00
#
#    Total_Amount Product_Category  Product_Brand Product_Type   Feedback  \
# 0        806.71      Electronics        Samsung       Tablet  Excellent
# 1       1063.43            Books  Penguin Books   Children's    Average
# 2       2466.85       Home Decor     Home Depot        Tools  Excellent
# 3        248.55          Grocery         Nestle    Chocolate        Bad
# 4       1185.17      Electronics          Apple       Tablet       Good
#
#   Shipping_Method Payment_Method Order_Status  Ratings
# 0        Standard    Credit Card   Processing     4.00
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195607 entries, 0 to 280215
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Country           195607 non-null  object
#  1   Age               195607 non-null  float64
#  2   Gender            195607 non-null  object
#  3   Income            195607 non-null  object
#  4   Customer_Segment  195607 non-null  int64
#  5   Total_Purchases   195607 non-null  float64
#  6   Total_Amount      195607 non-null  float64
#  7   Product_Category  195607 non-null  object
#  8   Product_Brand     195607 non-null  object
#  9   Product_Type      195607 non-null  object
#  10  Feedback          195607 non-null  object
#  11  Shipping_Method   195607 non-null  object
#  12  Payment_Method    195607 non-null  object
#  13  Order_Status      195607 non-null  object
#  14  Ratings           195607 non-null  float64
# dtypes: float64(4), int64(1), object(10)
# ...

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_columns),
        ('cat', OneHotEncoder(), categorical_columns)
    ]
)

# Transform the data
df_prepared = preprocessor.fit_transform(df_copy)

# Convert to DataFrame
df_prepared = pd.DataFrame(df_prepared.toarray(), columns=preprocessor.get_feature_names_out())

# %%
df_prepared = df_prepared.reset_index(drop=True)
df_copy = df_copy.reset_index(drop=True)
df_prepared['Customer_Segment'] = df_copy['Customer_Segment']

# %%
df_prepared['Customer_Segment'] = df_copy['Customer_Segment']

# %%
df_prepared.Customer_Segment.value_counts()
# Out:
# Customer_Segment
# 0    136207
# 1     59400
# Name: count, dtype: int64

# %%
X = df_prepared.drop('Customer_Segment', axis=1)
Y = df_prepared['Customer_Segment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=7)

# %%
X_train.shape
# Out:
# (156485, 86)

# %%
y_train
# Out:
# 128786    1
# 84300     1
# 82345     0
# 89219     0
# 36070     0
#          ..
# 53459     0
# 10742     0
# 49689     1
# 189636    1
# 61615     1
# Name: Customer_Segment, Length: 156485, dtype: int64

# %% [markdown]
# Deep Learning

# %%
def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='mako',
                          title=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    '''


    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))



    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)


    if title:
        plt.title(title)

# %%
# Fixing the seed for random number generators
np.random.seed(7)

import random
random.seed(7)

tf.random.set_seed(7)

# %%
def build_model(h):
    model = keras.Sequential()
    for i in range(h.Int('num_layers', 2, 10)):
        model.add(layers.Dense(units=h.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=256,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            h.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
     project_name='Customer_Segment_Prediction')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(X_train, y_train,
             epochs=5,
             validation_split = 0.2)
# Out:
# Trial 5 Complete [00h 02m 40s]
# val_accuracy: 1.0
#
# Best val_accuracy So Far: 1.0
# Total elapsed time: 00h 18m 18s
